# %% [markdown]
# market equilibrium -- happens no matter what through buying and selling securities.
# market efficiency -- what that market equilirbium should look like according to models.
# expected returns should only be a function of the beta and stuff like that/
#
# stock returns and normality -- fat tails, upside of normality assumption reduces parameters we need to to care about with expected return and stdev.
#
# there is always a joint hypothesis problem with market efficiency testing.
#
# how to mitigate jhp ==
# 1) use minimal assumptions
# 2) try multiple models
# 3) model the inefficiency -- miller (1977)
#
# r_j = (p_t+1 - p_t + D_t+1)/p_t
# pricing and expected returns are very similar
# E(r) = (E(P_t+1) - P_t + E(D_t+1))/P_t
#
# CAPM is supposed to hold for all i so we can make an exhaustion argument against it.
#
# diversification allows you to hedge against variance. pops up because securities are perfectly positively correlated with each other
#
# is covariance or variance more important when it comes to risk?
# -- Portfolio level: Risk = covariance or variance. doesnt matter
# -- security level: A securities contribution to your portfolios variance is the import part.
# ie covarienace of security with portfolio.
# Cov(r_i, r_p) = Risk of i in P
#
# MVE
# E(ri) = E(rNotI) + B_i,e( E(r_e) + E(r_notE))
# E(ri) = R_f + B_i,m(E(r_m) - r_f)
#
# B_i,m = Cov(i,m)/variance(m)
# in a time series the beta is also this equation
#
#
# Three factor models:
# E(rit) = rft + bi ( E(rmt) - rft) + si (E(SMBt)) + hi (E(HMLt))
#
# SMB = Return on small cap - return on big cap
# HML = High book to market - Low book to market
#
# Coef = (x' x)^-1 x' y
#
# Time Series:
# Rit - Rft = Alphai + Betai (Rmt - Rft) + Si (SMBt) + hi(HMLt) + Ei
#
# multivariate regression versus time series regression?
#
# Fama - Macbeth regressions --
# Rit = gamma0 + gamma1 BETAim + Gamma2 Rt-12,t-2. (momentum factor here == this tests the CAPM)
#
# Three factor model
# Rit = Gamma0 + Gamma1 Betai + Gamma2 Si + Gamma3 Hi + Gamma4 rt-2, t-12
#
#
#
# Alpha is your average abnormal return.
#
#
#
# Tracking portfolios:
# idea how do i construct something that mimics a portfolio or security as closely as possible
#
# say you think hormel is underpriced, you want to buy HRL and then you want to minimize risk so you short Meat processing stocks.
# -- you track it with something as close as possible without taking the unique part of HRL ie the underpricing.
#
# Tracking portfolios are just like this. Take out the risk factors and you are left with the unique parts of the portfolios.
#
# you can always think of a stock or a portfolio as a function of factors
# like two factor model: market, value/growth ie HML
# rHRL = alpha_i + rf(.4) + Beta( say 1.3) ( rm - rf) + .6 ( rv - rg) + ei <- has error because it is an individual stock
#
# tracking portfolio we want to replicate the loadings of the mfmodel with our portfolio
# so in this case
# 100% F
# 130% M
# -130% F
# 60% V
# -60% g
#
# so 130% in M 60% in v, -60% in growth portfolio, -30% in rf asset
#
# so Rtracking = rf + 1.3(rm-rf) + .6(rv - rg)
#
# rHRL - Rtracking = Alpha + Ei
#
# if instead of hormel and it was a perfect diversifed portfolio, there would be no idiosyncratic error and you would lock in only the alpha. if your r^2 is above .99 that is a good indicator you have low idiosyncratic risk. Arbitrage opportunity.
#
#
#
# Miller model: first time of testing market efficiency by modelling the inefficiency. Mispricing model.
# Two main assumptions:
# 1) differences of opinons (about value of securities)
# 2) shortselling constraints == short selling is costly ie fees or no selling period.
#
# 1a) optimistic investors are overconfident - dont need it but easiest way to do it/
#
# leads to implications -> if high difference of opinions ->
# stock prices high today -> Returns low on average in the future.
#
#
# assume some stock X:
# FV = 80
# optimists = 120
# pessamists = 60
#
# you would see a spike in buying, and price would push towards their price due to short selling restraints keeping it from FV
#
# as information comes out over time, the stocks dip back to FV again. ie future earnings and stuff like that.
#
# These affects are way bigger on smaller stocks since they are harder to short compared to larger market cap stocks
#
# joint hypothesis still applies but you expect this pattern due to mispricing so it is harder to argue against.
#
# shows it is inneficient because prices end up too high and optimists set the price which shouldnt be the case in a perfectly efficient world.
#
# valid questions for the exam:
# should be able to do what is on the slides for deriving the first order parameters and stuff
# here is the lagransien take the first order conditions. Where does risk show up in this equation/
#
# APT derivation -- heres a model i think holds, find a tracking portfolio and then questions about it with arbitrage opportunity available or not.
#
# there is a link between mfm and tangency portfolio - good to know
#
# do your best -- no one gets a bad grade -- dont worry too much in terms of grades and stuff like that. Study hard and good luck.
