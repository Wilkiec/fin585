# %% [markdown]
# we use E(r_not_e) to create a relationship
#
#
# Beta = cov(r_i, r_e) / covariance(r_e)

# %% [markdown]
# efficient portfolios: efficient in a mean variance sense, highest expected return for a given mean variance.
#
# we need to be able to find the boundary to identify the edge portfolios.
#
# investors should only be using the edge of the curve.
#
# when you have 3+ risky assets, an area is added to mean variance curve.
#
#
# risk free security -- zero variance. comes from a healthy government.
#
# finding a relationship between E(r) and risk allow us to make models.
