# %% [markdown]
# central prediction of the popular models of the time says that portfolios are mean variance efficent.
#
# SLB models have been disproved by multiple papers, with findings like
# - avg returns on small stocks with low ME have larger returns for their beta compared to larger stocks.
# - returns are posiively related to ratio of book value to market value
# - BE / ME (Book to market equity) also has a strong role in explaining cross-section of average return on japanese stocks
#
#
# paper suggests stock risks are multidimensional: size x BE/ME
#
# To get accurate individual betas, they took betas of portfolios and assigned those to individual stocks in those portfolios.

# %% [markdown]
# find a table and rejection specification in the reading that rejects the capm:
# TABLE II - panel B: little spread in avg returns despite a spread in the betas. No obvious relation between beta and avg returns.
