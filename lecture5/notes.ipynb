# %% [markdown]
# correlation = covariance / ?
#
#
# asset allocation graphs show when buying both or selling one and buying other or etc.

# %% [markdown]
# reset index is used to get rid of the multiindex created from a rolling sum.
#
# drop = true
#
# in terms of datapreparation, you want the date and stock in order.
#
# missing values don't equal themselves so that is a good way to parse for values.
# df.query("mom == mom and prclag >= 5").resetIndex(drop = True)
#
# df['bins'] = df.groupby('caldt').mom.transform(pd.qcut, 5, labels=False)
#
# should find the pattern that portfolio 0 has much lower returns than portfolio 4.

# %% [markdown]
# .rolling(3, (minimum amount optional) ).sum()
#
# rolls back 3 values and sums them all together.
#
# rolling includes the current observation.
#
# log returns are good until the returns become super big. monthly and daily are fine but when you get to yearly it can throw it off.
#
# rolling functions are built into groupby so we can use it while dividing permnumbers

# %% [markdown]
# we will learn a classic quant strategy in the homework.
#
# Called the: momentum effect.
#
# momentum portfolios are based on past returns
#
# Past winners will have higher returns
#
# shares outstanding: total amount of shares that a company has issued to the public. how many shares they have issued.
#
#
#
#
# t-12 to t-2
# you want to compound up the previous returns,
# you can use log returns instead... it is pretty close.
#
# How do we sum up log returns of the past 12 months for every data entry?
#
# log returns were initially less computationally expensive. (so we are doing it this way)

# %% [markdown]
# There are a huge amount of covariance in a portfolio
#
# variance is the natural parameter of portfolios.
#
# stdev is easier to interpret versus covariance since the units are weird for covariance.
