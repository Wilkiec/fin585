# %% [markdown]
# fama macbeth is a good approach if you think there is cross correlation in the securities.
#
# it takes it into account because it creates a distribution of gamma.
#
# find a table and rejection specification in the reading that rejects the capm:
# TABLE II: little spread in avg returns despite a spread in the betas. No obvious relation between beta and avg returns.

# %% [markdown]
# how to build a double sort portfolio.
#
# stock market raw data is sometimes negative to show that it is off of quote and not a trade that happened in the last 20 - 30 minutes before market close.
# -- remember to do this
#
# double sort is shown in 12-doublesort.ipynb
#
# people typically perfer the nyse breakpoints since nyse has the largest stocks?
# -- look into this more prolly.

# %% [markdown]
# ## Multi Factor Models:
#
# is there a terrorism factor in security returns?
