# %% [markdown]
# Testing CAPM:
# SML - security market line
#
# time series testing:
# we run time series regressions. Need constant betas' over time.
#
# alpha = average abnormal return.

# %% [markdown]
# Today: testing the CAPM
#
# Nice thing about testing CAPM is that the general testing framework applies to all the models we will go over sooner.
#
# first: HW review.
#
# expected utility: pleasure/happiness comes from having more wealth.
# all our risky allocations are T, and that is true for everyone. WHen we add everyone up, we aggragate up to the market portfolio. Since we are all investing in the same weighted sums of the risky assets, prices have to be set at the market portfolio. Complete agreement is the big part of this idea.
#
# riskless -- doesnt co-vary with the rest of the portfolio -- beta = 0;
