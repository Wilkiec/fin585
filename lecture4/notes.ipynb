# %% [markdown]
# It is easier to think of the problems in terms of the basic rules we were taught ie Joint hypothesis theorem.
#
# you cannot escape the joint hypothesis theorem. Testing market efficiency is hopeless...ish
#
# want to write the model so it has atleast one testable prediction.
#
# always can decompose returns into expected return + error
#
# unexpected componenent is normally super big.
#
# being able to predict unexpected returns implies an unefficient model.
#
# the world of assets and securities is super noisy.
#
# You cannot have higher expected returns with the same amount of risk.
# any asset with the same risk will have the same expected returns.
#
# our future models will have models of risk.
#
# market efficiency is a statement of using all available information
#
# whatever is the correct measure of risk couples with the market return
#
#
# stock returns are leptokurdic (they have fail tails)
#
# Monthly returns are fairly symmetrical and the most normal of the return horizons.
#
# annual has more skew since it is uncapped upwards but capped on the downside.
#
# natural log ( 1 + return ) makes it more symmetrical.
#
# we worry most about the fat tails. variance and stdev can be misleading when we have those big tails
#
# much more likely to get a 6 stdev event with this.
#
# lots of literature in skewness. Typically research likes normalizing the data
#
# security returns are jointly multivariate normal.
#
# portfolio returns are normal only if security returns are joinly multivariate normal.
#
#
# Two main exonomic assumptions:
# investors like expexted return but are risk averse.
#
# because we are in a normal world we can summarize that risk with standard deviation.
#
#
# assumptions imply two parameters matter: E(r) and sigma of portfolio returns
#
# risk is particular to the portfolio you return.
#
# covariance is king in finance
# matters most in security level.
#
# we like expected return and dislike stdev at the portfolio level.
#
#
# most securities have non zero covarience with each other.
#
#
# we will start with 2 asset portfolio and then move to n asset portfolio.
#
# short selling shows up as negative weight/
#
#
# in finance, stdev is used much more since it has the same units as what we are looking at since variance is squared.
#
# the degree of covariance is your diversification.
#
#
# with N asset portfolios, the variance is harder to find.
#
# variance of the portfolio can be written as a double sum of all the assets times all the assets times covariance between
