# %% [markdown]
# test is a week from now. only stuff we went through in class
#
# ## Risk Factors:
#
# crime factor example:
# largely solved by policing and insurance
#
#
# market primarily captures wealth channel. other factors have to be non related to wealth channel ie terrorism or sum like that..
#
# assets with low return when crime is high, will have high returns when the market is good.
#
#
# three conditions for risk factors beyond market factor ->
# 1. variable explains differences in expected returns
# 2. linked to marginal utility
# 3. not captured by the market factor <- wealth channel

# %% [markdown]
# ## factor model basics:
#
# potentially k factors.
#
# why are we always linear? -- normallity leads to linear structure models.
#
# factor loadings: slopes from multivariate regressions.
#
# covariate, pick up how strongly stuff is related,
#
# factor models are easier to test if factors are zero cost portfolios
#
#
# how do we take a variable and trade on it?
# project it into the tradeable space.
# example: Crime = return on gun stocks - return on jewelery stocks
# (this is a zero cost portfolio cuz its shorting stocks and that pays for guns)
# this has a factor loading of 1 because guns and jewelery are related in crime
#
#
# factor loading synonms:
# loadings, factor betas, betas, slopes, coefficients, sensitivies.
#
#
# ### assumptions for the APT:
# 1. covariation in security returns is captured by a relatively small number k of comon factors <- non diversifiable>
# 2. riskfree borrowing and lending
# 3. there are no arbitrage opportunities
# 4. there are an infinite nnumber of securities
#
# what is ICAPM?
#
# high b/m stocks have high value -- value stocks
# low b/m stocks have had high growth
#
# Check out final thoughts on factor models ipynb
#
# alpha is always the intercept in mfmodels
