# %% [markdown]
# we want to think like a financial economist. He always brings a hardcopy of slides to class.
#
# Stochastic discount factor: very important in asset pricing models.
# The true value of a model is determined by its ability to predict the world. my objective is to build models to help us do things. Doesnt need to exactly explain everything but rather help in certain situations.
#
# schowzen model of atonement == gods power comes from his honor and every part of matter has intelligence and chooses to obey god which makes the world move the way it does. If god let humans sin and not give them justice, he would lose his honor and everything would spiral out of control.
#
#
# They don't need to be perfect to be useful.
#
# intuition: we pay more money for things we enjoy things that are expected to give us additional utility. what gives us utility? additional consumption
#
# assume we can aggregate everyone into represetnative investor. the tastes preferences and consumption levels of this investor represent the ... .. .. of everyone in the economy.
# law of diminishing returns/
#
#
# Two period model: assume at end of the year we can only have a recession or an expansion: BMW pays if there is an expansion. Ace will pay if there is a recession. assuming an equal chance of a recession or a expansion, we can expect the average dividend of 1 dollar. (both pay 2 if they pay.) in the case that there is an expansion and you get 2 bucks from bmw. The increase in utility is very low. When getting 2 bucks from Ace during a recession, the money will add a lot more utility. expected cash flows is the same for each because in terms of cash they both pay .5(2) + .5(0). var(x) = .5(0-1)^2 + .5(2-1)^2 variance of each is also the same. We dont value the cash flows the same.
#
# This implies we should pay a higher price for ace than for bmw
# E(r) = (e(cash flow) / price) - 1
#
#
# variance doesnt determine the prices we are willing to pay, rather the beta's relative to aggregate wealth.
#
# the intiution that assets with higher variance should demand higher returns and higher betas is not the case at all because insurance and things like that.
#
# when slope of utility function is steep those r worse times. When slope of utility is flat there are good times.
#
# Beta of an asset in a regression = cov(x,y)/var(x) = correlation of sigma y / sigma x.  volatility in isolation tells you really nothing.
#
# assets that tend to pay off in bad times tend to command higher prices and lower returns/ assets that crash in bad times tend to command lower prices and higher expected returns/
#
#
# it is hard to measure aggregate consumption. What factors are important? market return interest rates others? some factors may be positively correlated with wealth and other negatively correlated with wealth. The data we have turns out to not be very good.
#
# those with lower betas tend to earn higher returns and those with higher betas earn lower?
#
# leads us to the idea we can model the betas relative to the factors of wealth rather than marginal utility itself.
#
# Linear factor models for MBAs:
# explain why expected returns are different across securities. Factors do not appear in the model instead factor betas appear in the model.
#
#
#
#
# suppose our factor is unemployment -- when unemployment is high, utility is super steep. WHen an assset has a high beta when unemployment is high, it has a negative risk premium.
# any factor that has positive correlation with marginal utility of consumption will have a negative risk premium
#
# suppose factor of GDP growth factor. negatively correlated with marginal utility of consumption. Therefore our assets with positive betas with gdp growth are more like the opposite of insurance. We expect risk premium to be positive.
#
# weakness of fama french model is that it is not an economical model it is an empirical model. An optimal way is to think about the factors and put them in. Fama french does not have good economical assumptions.
#
#
#
# questions:
# can we always model expected returns as linear functions of betas?
