# %% [markdown]
# Cross sectional tests.
#
# we need to estimated expected returns since we dont have these.
#
# This is a complication.
#
# What do we use to estimate? could run cross sectional regression where we use the average return and estimated beta from some sample period.

# %% [markdown]
# left merge is used because we want to keep the stock data unmolested
