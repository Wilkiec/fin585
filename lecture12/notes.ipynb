# %% [markdown]
# good to know given this minimization problem what are the first order conditions and what do they mean. Do you understand the implications of those first order conditions? also know about tracking portfolios. How do i make a tracking portfolio?
#
# what is a value and growth portfolio?
#
# fama and french call it a HML factor.
#
# How do we interpret the coefficients in a multifactor model?
# - positive loadings show a lean towards positive - negative in portfolios.
# - compare it to the market portfolio
#
# look up 5 and 6 factor models
#
#
# all mf models have a single factor representation. can be mapped to tangency portfolio.
#
# betting against beta strategy. -- what is it?
#
# diether paper introduces miller model. -- Ed Miller
#
# Assumptions:
# 1) differences of opinion -- breaks complete agreement
# 2) There are short selling constraints -- shorting is expensive and not frictionless
#
# 3) in extreme version no short selling period.
#
# Two types of people in the market, optimists and pessamists
# requires optimists to be overconfident -- generally supported in psycology literature
#
# first taste of behavioural
